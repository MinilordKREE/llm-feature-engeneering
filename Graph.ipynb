# %% [markdown]
# ## Epochs

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for each epoch
# Data for each epoch
# Data for each epoch
data = {
    5: {
        "Logistic Regression": 0.9019279358908576,
        "Random Forest": 0.9030266176784532,
        "AdaBoost": 0.8614177506120406,
        "Gradient Boosting": 0.9039873859095217,
        "Support Vector Machine": 0.7370386175436231,
        "XGBoost": 0.9061724175383798,
    },
    10: {
        "Logistic Regression": 0.904397853207642,
        "Random Forest": 0.8963189589630078,
        "AdaBoost": 0.8578735419951586,
        "Gradient Boosting": 0.8954511372531394,
        "Support Vector Machine": 0.7409384626140281,
        "XGBoost": 0.9061637060257752,
    },
    20: {
        "Logistic Regression": 0.911692205705554,
        "Random Forest": 0.8973529997790288,
        "AdaBoost": 0.8923253821118114,
        "Gradient Boosting": 0.8987827602436427,
        "Support Vector Machine": 0.7531891976244961,
        "XGBoost": 0.8968104178604734,
    },
    30: {
        "Logistic Regression": 0.9596479739928017,
        "Random Forest": 0.9496334435692981,
        "AdaBoost": 0.9239948415061503,
        "Gradient Boosting": 0.9394847573497925,
        "Support Vector Machine": 0.7612041287925605,
        "XGBoost": 0.9329111408236361,
    },
    40: {
        "Logistic Regression": 0.9592347476744955,
        "Random Forest": 0.9693362122023599,
        "AdaBoost": 0.9411994471972225,
        "Gradient Boosting": 0.9618415098956442,
        "Support Vector Machine": 0.7658857466020981,
        "XGBoost": 0.9589923633816848,
    },
    50: {
        "Logistic Regression": 0.9632184607164215,
        "Random Forest": 0.9746056760910301,
        "AdaBoost": 0.9552906072216416,
        "Gradient Boosting": 0.9718138223166031,
        "Support Vector Machine": 0.768772123659035,
        "XGBoost": 0.9690514463632743,
    },
    60: {
        "Logistic Regression": 0.9656623908095915,
        "Random Forest": 0.9708229345737689,
        "AdaBoost": 0.9410117838875717,
        "Gradient Boosting": 0.9676741484802294,
        "Support Vector Machine": 0.766549654248579,
        "XGBoost": 0.9607748377359056,
    },
    70: {
        "Logistic Regression": 0.9545221189774399,
        "Random Forest": 0.971813391609832,
        "AdaBoost": 0.954028321779156,
        "Gradient Boosting": 0.9651022123346928,
        "Support Vector Machine": 0.7691155580024694,
        "XGBoost": 0.9679073069091608,
    },
        80: {
        "Logistic Regression": 0.9723636962880567,
        "Random Forest": 0.9737242328113667,
        "AdaBoost": 0.9496472524029068,
        "Gradient Boosting": 0.9726066748313691,
        "Support Vector Machine": 0.7687798464187043,
        "XGBoost": 0.9656843630970439,
    },
    90: {
        "Logistic Regression": 0.9696815841020513,
        "Random Forest": 0.9766076535969009,
        "AdaBoost": 0.9569850351244493,
        "Gradient Boosting": 0.9575696677565422,
        "Support Vector Machine": 0.7678895979945294,
        "XGBoost": 0.9666166622347564,
    },
        100: {
    "Logistic Regression": 0.9609827904555381,
    "Random Forest": 0.9687014752643229,
    "AdaBoost": 0.9621385277818352,
    "Gradient Boosting": 0.9695088045202989,
    "Support Vector Machine": 0.7676694968471016,
    "XGBoost": 0.9657210792887471,
    }
}


baselines_data = {
    "Logistic Regression": {"mean": 0.9039},
    "Random Forest": {"mean": 0.9046},
    "AdaBoost": {"mean": 0.8549},
    "Gradient Boosting": {"mean": 0.8888},
    "Support Vector Machine": {"mean": 0.9171},
    "XGBoost": {"mean": 0.8824},
}

# Extract mean values and use them as baselines in your plot
baselines = {model: metrics["mean"] for model, metrics in baselines_data.items()}

# Create the plot with a colorblind-friendly color palette
plt.figure(figsize=(12, 6))
palette = sns.color_palette("husl", len(data[5]))

# Plot each model's line
for idx, model in enumerate(data[5].keys()):
    plt.plot(
        list(data.keys()), 
        [epoch_data[model] for epoch_data in data.values()], 
        label=model, 
        color=palette[idx],
        marker='o'
    )

# Plot each baseline
baseline_palette = sns.color_palette("Set2", len(baselines))
for idx, (name, value) in enumerate(baselines.items()):
    plt.axhline(y=value, linestyle='--', linewidth=1.5, label=f'{name} Baseline', color=baseline_palette[idx])

# Add labels and legend
plt.title('Model Performance Across Epochs', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Mean Performance', fontsize=14)
plt.legend(title='Model', fontsize=12, loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## k values

# %%
performance_data = {
    1: {
        "Logistic Regression": 0.941142696274324,
        "Random Forest": 0.9436527404810683,
        "AdaBoost": 0.8834793691456649,
        "Gradient Boosting": 0.9267394773342122,
        "Support Vector Machine": 0.7264752655712983,
        "XGBoost": 0.9387566531711877,
    },
    5: {
        "Logistic Regression": 0.9495846089120098,
        "Random Forest": 0.9343942527487206,
        "AdaBoost": 0.9009401742052836,
        "Gradient Boosting": 0.9156499177911858,
        "Support Vector Machine": 0.7301447848900574,
        "XGBoost": 0.9438487782284593,
    },
    10: {
        "Logistic Regression": 0.9536162614901956,
        "Random Forest": 0.9360768792860006,
        "AdaBoost": 0.9081135417954105,
        "Gradient Boosting": 0.9225874478314227,
        "Support Vector Machine": 0.7363754614492471,
        "XGBoost": 0.9458557394486204,
    },
    15: {
        "Logistic Regression": 0.9564986435857774,
        "Random Forest": 0.922464836225311,
        "AdaBoost": 0.9044983289825709,
        "Gradient Boosting": 0.9207924742418626,
        "Support Vector Machine": 0.7429470804947261,
        "XGBoost": 0.9456312525826801,
    },
    20: {
        "Logistic Regression": 0.9565173624765764,
        "Random Forest": 0.9229313665639214,
        "AdaBoost": 0.9187169507458718,
        "Gradient Boosting": 0.9161185991668009,
        "Support Vector Machine": 0.7500776121117241,
        "XGBoost": 0.9369608980673126,
    },
    25: {
        "Logistic Regression": 0.9524899320731727,
        "Random Forest": 0.929516473597675,
        "AdaBoost": 0.9078170182856871,
        "Gradient Boosting": 0.9184594080715698,
        "Support Vector Machine": 0.7546421263681183,
        "XGBoost": 0.9449710927093206,
    },
    30: {
        "Logistic Regression": 0.9529306287444961,
        "Random Forest": 0.9198351129637745,
        "AdaBoost": 0.898912269400219,
        "Gradient Boosting": 0.9134372285454969,
        "Support Vector Machine": 0.760656943929469,
        "XGBoost": 0.9443156294124035,
    },
    40: {
        "Logistic Regression": 0.9516037822296628,
        "Random Forest": 0.9189597120631603,
        "AdaBoost": 0.9029203267379019,
        "Gradient Boosting": 0.9219957503598586,
        "Support Vector Machine": 0.7716737389966905,
        "XGBoost": 0.9427411477274287,
    },
    50: {
        "Logistic Regression": 0.9551725386356459,
        "Random Forest": 0.9228126662746611,
        "AdaBoost": 0.9137825068132818,
        "Gradient Boosting": 0.9220136877363425,
        "Support Vector Machine": 0.7807995141128252,
        "XGBoost": 0.9465298617119158,
    },
        65: {
        "Logistic Regression": 0.9527198770550642,
        "Random Forest": 0.9090686883667974,
        "AdaBoost": 0.906178657168646,
        "Gradient Boosting": 0.9191345790122207,
        "Support Vector Machine": 0.7947192940403915,
        "XGBoost": 0.9474240214529426,
    },
    80: {
        "Logistic Regression": 0.9524974076446082,
        "Random Forest": 0.9023302659520679,
        "AdaBoost": 0.900722895747738,
        "Gradient Boosting": 0.9126499777156061,
        "Support Vector Machine": 0.804283664727862,
        "XGBoost": 0.9447775767812845,
    },
    100: {
        "Logistic Regression": 0.9478073255106996,
        "Random Forest": 0.9062531856695741,
        "AdaBoost": 0.9144884015036036,
        "Gradient Boosting": 0.904641533366042,
        "Support Vector Machine": 0.8173124147169382,
        "XGBoost": 0.942970103956385,
    },
        130: {
        "Logistic Regression": 0.9451493903314445,
        "Random Forest": 0.9042549459494212,
        "AdaBoost": 0.9091247988474537,
        "Gradient Boosting": 0.9102284943115496,
        "Support Vector Machine": 0.8355769785358218,
        "XGBoost": 0.9422947058023068,
    },
    160: {
        "Logistic Regression": 0.9366730461205803,
        "Random Forest": 0.9042366577653933,
        "AdaBoost": 0.9060217575582797,
        "Gradient Boosting": 0.918038171855747,
        "Support Vector Machine": 0.8478325836538666,
        "XGBoost": 0.9452055470038413,
    },
    200: {
        "Logistic Regression": 0.9407196897912508,
        "Random Forest": 0.9038980136303089,
        "AdaBoost": 0.8863345081016568,
        "Gradient Boosting": 0.917596980807956,
        "Support Vector Machine": 0.8594145409102769,
        "XGBoost": 0.9413995972579583,
    },
}

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
palette = sns.color_palette("husl", len(performance_data[1]))

# Plot each model's line
for idx, model in enumerate(performance_data[1].keys()):
    plt.plot(
        list(performance_data.keys()), 
        [k_data[model] for k_data in performance_data.values()], 
        label=model, 
        color=palette[idx],
        marker='o'
    )

# Add labels and legend
plt.title('Model Performance Across Different k Values', fontsize=16)
plt.xlabel('k Value', fontsize=14)
plt.ylabel('Mean AUC Performance', fontsize=14)
plt.legend(title='Model', fontsize=12, loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()
